# %%
from getData import get_data
from technical_indicator import calculate_LR, calculate_rsi
from Returns import cummulative_returns
# %load_ext autoreload

# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def run_all(ticker, start_date):
    data=get_data(ticker, start_date)
    calculate_LR(data)
    calculate_rsi(data)
    cummulative_returns(data)
    return data

# %%
run_all('RELIANCE.NS', '2014-01-01')
# run_all()
data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2014-01-01   205.141968   205.324844   202.890427   203.164734   179.935059
# 2014-01-02   202.913284   204.810532   198.890228   200.010284   177.141281
# 2014-01-03   199.233093   199.633118   195.438614   197.553009   174.964951
# 2014-01-06   197.061554   197.324432   194.295700   195.427185   173.082199
# 2014-01-07   195.347183   196.570099   192.021301   192.489899   170.480759
# ...                 ...          ...          ...          ...          ...
# 2025-02-10  1264.500000  1266.500000  1245.550049  1253.650024  1253.650024
# 2025-02-11  1264.550049  1264.550049  1230.099976  1234.849976  1234.849976
# 2025-02-12  1219.449951  1226.900024  1193.349976  1216.550049  1216.550049
# 2025-02-13  1217.050049  1228.000000  1212.000000  1216.099976  1216.099976
# 2025-02-14  1219.000000  1224.000000  1205.449951  1217.250000  1217.250000
#
#               Volume         STD        +1STD        -1STD        +2STD  \
# Date
# 2014-01-01   5849398  110.909753    94.054988  -127.764518   204.964741
# 2014-01-02   6023632  110.909753    94.408751  -127.410754   205.318504
# 2014-01-03  12833897  110.909753    94.762515  -127.056991   205.672268
# 2014-01-06  13315857  110.909753    95.823806  -125.995700   206.733559
# 2014-01-07  17311470  110.909753    96.177570  -125.641936   207.087323
# ...              ...         ...          ...          ...          ...
# 2025-02-10   6970972  110.909753  1529.627921  1307.808415  1640.537674
# 2025-02-11   8859714  110.909753  1529.981685  1308.162179  1640.891437
# 2025-02-12  21131654  110.909753  1530.335448  1308.515942  1641.245201
# 2025-02-13   8511216  110.909753  1530.689212  1308.869706  1641.598965
# 2025-02-14  10298145  110.909753  1531.042975  1309.223470  1641.952728
#
#                   -2STD     d_rtn   cum_rtn
# Date
# 2014-01-01  -238.674271       NaN       NaN
# 2014-01-02  -238.320507 -0.015527  0.984473
# 2014-01-03  -237.966744 -0.012286  0.972378
# 2014-01-06  -236.905453 -0.010761  0.961915
# 2014-01-07  -236.551689 -0.015030  0.947457
# ...                 ...       ...       ...
# 2025-02-10  1196.898662 -0.010302  6.170608
# 2025-02-11  1197.252426 -0.014996  6.078072
# 2025-02-12  1197.606190 -0.014820  5.987998
# 2025-02-13  1197.959953 -0.000370  5.985783
# 2025-02-14  1198.313717  0.000946  5.991443
#
# [2745 rows x 13 columns]

# %%
stock_list = ['ICICIBANK.NS', 'HDFCBANK.NS', 'AXISBANK.NS','KOTAKBANK.NS','^NSEI']
stock_list
# Out:
# ['ICICIBANK.NS', 'HDFCBANK.NS', 'AXISBANK.NS', 'KOTAKBANK.NS', '^NSEI']

# %%
dict_stock  = {}
for stock in stock_list:
    print(stock)
    dict_stock[stock] = run_all(stock,'2021-01-01')
# Out:
# ICICIBANK.NS
# [*********************100%%**********************]  1 of 1 completed
# HDFCBANK.NS
# [*********************100%%**********************]  1 of 1 completed
# AXISBANK.NS
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# KOTAKBANK.NS
# ^NSEI
# [*********************100%%**********************]  1 of 1 completed

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,9))
for key in dict_stock:
    plt.plot(dict_stock[key]['cum_rtn'], label = key)
plt.legend()
plt.show()
