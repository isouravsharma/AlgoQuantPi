# %%
# To download top 50 stocks

# %%
# libraries 

from getData import get_data, get_ohlcv
from technical_indicator import LR, MACD, RSI, BB, ATR, ADX, RENKO, anomaly, historical_volatility, get_support_resistance_levels, VWAP
from Returns import cummulative_returns, CAGR, volatility, SHARPE, SORTINO, MAXDROWDOWN, CALMAR
from signals import stratgey1_mean_reversion, label_sd_categories


from plotly.subplots import make_subplots
import plotly.graph_objects as go

import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd
import numpy as np
import datetime as dt
import copy
import os

# %load_ext autoreload
# %autoreload 2
pd.set_option('mode.chained_assignment', None)

# %% [markdown]
# ## Getting Data

# %%
# tickers = ['ICICIBANK.NS']
# tickers

tickers = [
    'ADANIPORTS.NS', 'ASIANPAINT.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAJFINANCE.NS',
    'BAJAJFINSV.NS', 'BPCL.NS', 'BHARTIARTL.NS', 'CIPLA.NS', 'COALINDIA.NS',
    'DIVISLAB.NS', 'DRREDDY.NS', 'EICHERMOT.NS', 'GAIL.NS', 'GRASIM.NS',
    'HCLTECH.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'HINDALCO.NS', 'HINDPETRO.NS',
    'HINDUNILVR.NS', 'ITC.NS', 'ICICIBANK.NS', 
    'IOC.NS', 'INDUSINDBK.NS', 'INFY.NS', 'JSWSTEEL.NS', 'KOTAKBANK.NS',
    'LT.NS', 'M&M.NS', 'MARUTI.NS', 'NTPC.NS', 'ONGC.NS', 'POWERGRID.NS',
    'RELIANCE.NS', 'SBIN.NS', 'SUNPHARMA.NS', 'TCS.NS', 'TATAMOTORS.NS',
    'TATASTEEL.NS', 'TECHM.NS', 'TITAN.NS', 'UPL.NS', 'ULTRACEMCO.NS',
    'VEDL.NS', 'WIPRO.NS', 'YESBANK.NS', 'ZEEL.NS'
]

# tickers = [
#     'ADANIPORTS.NS', 'ASIANPAINT.NS', 
#     'CIPLA.NS', 
#     'ITC.NS', 'ICICIBANK.NS',
#     'IOC.NS',  'INFY.NS', 'JSWSTEEL.NS', 'KOTAKBANK.NS',
    
#     'RELIANCE.NS', 
#     'VEDL.NS', 'WIPRO.NS'
# ]

# %%
# Store data in dictionary
ohlcv_dict = {}
for stock in tickers:
    ohlcv_dict[stock] = get_ohlcv(ticker=stock, period = '6mo', interval='1d', multi_level_index=False)
    # ohlcv_dict[stock] = ohlcv_dict[stock].between_time('09:35', '16:00')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
data = copy.deepcopy(ohlcv_dict)

# %% [markdown]
# # Calculation on Data

# %%
for stock_name in tickers:
    cummulative_returns(data[stock_name])
    ATR(data[stock_name])
    anomaly(data[stock_name])
    support, resistnace  = get_support_resistance_levels(data[stock_name])
    data[stock_name]['support'] = support
    data[stock_name]['resistance'] = resistnace
    historical_volatility(data[stock_name])
    historical_volatility(data[stock_name])
    RSI(data[stock_name])
    VWAP(data[stock_name])
    BB(data[stock_name])
    data[stock_name]['Close'] = round(data[stock_name]['Close'],2)
    data[stock_name]['Signal'] = data[stock_name].apply(stratgey1_mean_reversion, axis=1)
    data[stock_name]['m_half_50'] = data[stock_name]['Close'].ewm(halflife=50).mean()
    data[stock_name]['Distance_From_Mean'] = (data[stock_name]['Close'] - data[stock_name]['m_half_50'])
    label_sd_categories(data[stock_name])
    print(f'Now processing {[stock_name]}')
# Out:
# Now processing ['ADANIPORTS.NS']
# Now processing ['ASIANPAINT.NS']
# Now processing ['AXISBANK.NS']
# Now processing ['BAJAJ-AUTO.NS']
# Now processing ['BAJFINANCE.NS']
# Now processing ['BAJAJFINSV.NS']
# Now processing ['BPCL.NS']
# Now processing ['BHARTIARTL.NS']
# Now processing ['CIPLA.NS']
# Now processing ['COALINDIA.NS']
# Now processing ['DIVISLAB.NS']
# Now processing ['DRREDDY.NS']
# Now processing ['EICHERMOT.NS']
# Now processing ['GAIL.NS']
# Now processing ['GRASIM.NS']
# Now processing ['HCLTECH.NS']
# Now processing ['HDFCBANK.NS']
# Now processing ['HEROMOTOCO.NS']
# Now processing ['HINDALCO.NS']
# Now processing ['HINDPETRO.NS']
# Now processing ['HINDUNILVR.NS']
# Now processing ['ITC.NS']
# Now processing ['ICICIBANK.NS']
# Now processing ['IOC.NS']
# Now processing ['INDUSINDBK.NS']
# Now processing ['INFY.NS']
# Now processing ['JSWSTEEL.NS']
# Now processing ['KOTAKBANK.NS']
# Now processing ['LT.NS']
# Now processing ['M&M.NS']
# Now processing ['MARUTI.NS']
# Now processing ['NTPC.NS']
# Now processing ['ONGC.NS']
# Now processing ['POWERGRID.NS']
# Now processing ['RELIANCE.NS']
# Now processing ['SBIN.NS']
# Now processing ['SUNPHARMA.NS']
# Now processing ['TCS.NS']
# Now processing ['TATAMOTORS.NS']
# Now processing ['TATASTEEL.NS']
# Now processing ['TECHM.NS']
# Now processing ['TITAN.NS']
# Now processing ['UPL.NS']
# Now processing ['ULTRACEMCO.NS']
# Now processing ['VEDL.NS']
# Now processing ['WIPRO.NS']
# Now processing ['YESBANK.NS']
# Now processing ['ZEEL.NS']

# %%
# data

# %%
for stock_name in tickers:
    df = data[stock_name]
    resistance = df.loc[df['resistance']>1]['resistance'].tail(5)
    resistance.name = 'Close'
    
    resistance_levels = [
        {"date": date.strftime("%Y-%m-%d"), "Close": round(Close,2)}
        for date, Close in resistance.items()
    ]
    # resistance_levels
    
    support = df.loc[df['support']>1]['support'].tail(5)
    support.name = 'Close'
    
    support_levels = [
        {"date": date.strftime("%Y-%m-%d"), "Close": round(Close,2)}
        for date, Close in support.items()
    ]
    
    
    # Buy
    buy = df.loc[df['Signal'] ==1]['Close'].tail(5)
    buy.name = 'Close'
    
    # Sell
    sell = df.loc[df['Signal'] ==-1]['Close'].tail(5)
    sell.name = 'Close'

    fig = go.Figure()
    #Close
    fig.add_trace(go.Scatter(
        x=data[stock_name].index,
        y=data[stock_name]['Close'],
        mode='lines',  # Set the mode to 'lines' for a line chart
        name='Close'# Use the name for each line from the dictionary
    ))   

    fig.add_trace(go.Scatter(
        x=data[stock_name].index,
        y=data[stock_name]['m_half_50'],
        mode='lines',  # Set the mode to 'lines' for a line chart
        name='MB'# Use the name for each line from the dictionary
    ))
    
    # fig.add_trace(go.Scatter(
    #     x=data[stock_name].index,
    #     y=data[stock_name]['UB'],
    #     mode='lines',  # Set the mode to 'lines' for a line chart
    #     name='UB'# Use the name for each line from the dictionary
    # ))
        

    # fig.add_trace(go.Scatter(
    #     x=data[stock_name].index,
    #     y=data[stock_name]['LB'],
    #     mode='lines',  # Set the mode to 'lines' for a line chart
    #     name='LB'# Use the name for each line from the dictionary
    # )) 
    
    
    for level in support_levels:
        fig.add_hline(
            y=level["Close"],
            line=dict(color="green", dash="dash"),
            annotation_text=f"Support ({level['Close']})",
            annotation_position="bottom left"
        )
    
    # Add resistance lines
    for level in resistance_levels:
        fig.add_hline(
            y=level["Close"],
            line=dict(color="red", dash="dash"),
            annotation_text=f"Resistance ({level['Close']})",
                    annotation_position="top left"
        )
    
    # #Buy
    # fig.add_trace(go.Scatter(
    #     x=buy.index,
    #     y=buy.values,
    #     mode='markers',
    #     name='Buy Signal',
    #     marker=dict(color='green', size=20, symbol='triangle-up')
    #     ))
    
    
    # #Sell
    # fig.add_trace(go.Scatter(
    #     x=sell.index,
    #     y=sell.values,
    #     mode='markers',
    #     name='Sell Signal',
    #     marker=dict(color='red', size=20, symbol='triangle-down')
    #     ))
    

    fig.add_trace(go.Scatter(
        x=data[stock_name][data[stock_name]['Label'] == 'ABOVE 2 SD'].index,
        y=data[stock_name][data[stock_name]['Label'] == 'ABOVE 2 SD']['Close'],
        mode='markers',
        name='ABOVE 2 SD',
        marker=dict(color='green', size=10, symbol='triangle-up')
    ))
    

    fig.add_trace(go.Scatter(
        x=data[stock_name][data[stock_name]['Label'] == 'ABOVE 3 SD'].index,
        y=data[stock_name][data[stock_name]['Label'] == 'ABOVE 3 SD']['Close'],
        mode='markers',
        name='Buy 3 SD',
        marker=dict(color='green', size=20, symbol='triangle-up')
    ))


    fig.add_trace(go.Scatter(
        x=data[stock_name][data[stock_name]['Label'] == 'BELOW 2 SD'].index,
        y=data[stock_name][data[stock_name]['Label'] == 'BELOW 2 SD']['Close'],
        mode='markers',
        name='BELOW 2 SD',
        marker=dict(color='red', size=10, symbol='triangle-down')
    ))



    fig.add_trace(go.Scatter(
        x=data[stock_name][data[stock_name]['Label'] == 'BELOW 3 SD'].index,
        y=data[stock_name][data[stock_name]['Label'] == 'BELOW 3 SD']['Close'],
        mode='markers',
        name='BELOW 3 SD',
        marker=dict(color='red', size=20, symbol='triangle-down')
    ))
    
    # Customize the layout
    fig.update_layout(
        title=f"{stock_name} Signal Chart",
        xaxis_title="Year",
        yaxis_title="Cumulative Return",
        autosize=False,
        width=1100,
        height=800,
        template='plotly_white'
    )
        
    
    
    # Path where you want to save
    output_dir = "../PlotlyOutput"
    
    # Create the directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Full file path
    file_path = os.path.join(output_dir, f"{stock_name}.png")
    
    # Save the figure
    fig.write_image(file_path)

    print(f"Output saved for {stock_name}")
# Out:
# Output saved for ADANIPORTS.NS
# Output saved for ASIANPAINT.NS
# Output saved for AXISBANK.NS
# Output saved for BAJAJ-AUTO.NS
# Output saved for BAJFINANCE.NS
# Output saved for BAJAJFINSV.NS
# Output saved for BPCL.NS
# Output saved for BHARTIARTL.NS
# Output saved for CIPLA.NS
# Output saved for COALINDIA.NS
# Output saved for DIVISLAB.NS
# Output saved for DRREDDY.NS
# Output saved for EICHERMOT.NS
# Output saved for GAIL.NS
# Output saved for GRASIM.NS
# Output saved for HCLTECH.NS
# Output saved for HDFCBANK.NS
# Output saved for HEROMOTOCO.NS
# Output saved for HINDALCO.NS
# Output saved for HINDPETRO.NS
# Output saved for HINDUNILVR.NS
# Output saved for ITC.NS
# Output saved for ICICIBANK.NS
# Output saved for IOC.NS
# Output saved for INDUSINDBK.NS
# Output saved for INFY.NS
# Output saved for JSWSTEEL.NS
# Output saved for KOTAKBANK.NS
# Output saved for LT.NS
# Output saved for M&M.NS
# Output saved for MARUTI.NS
# Output saved for NTPC.NS
# Output saved for ONGC.NS
# Output saved for POWERGRID.NS
# Output saved for RELIANCE.NS
# Output saved for SBIN.NS
# Output saved for SUNPHARMA.NS
# Output saved for TCS.NS
# Output saved for TATAMOTORS.NS
# Output saved for TATASTEEL.NS
# Output saved for TECHM.NS
# Output saved for TITAN.NS
# Output saved for UPL.NS
# Output saved for ULTRACEMCO.NS
# Output saved for VEDL.NS
# Output saved for WIPRO.NS
# Output saved for YESBANK.NS
# Output saved for ZEEL.NS
