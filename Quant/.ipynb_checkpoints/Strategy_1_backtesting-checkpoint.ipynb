# %%
from getData import get_data, get_ohlcv
from technical_indicator import LR, MACD, RSI, BB, ATR, ADX, RENKO
from Returns import cummulative_returns, CAGR, volatility, SHARPE, SORTINO, MAXDROWDOWN, CALMAR

import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd
import numpy as np
import datetime as dt
import copy
# %load_ext autoreload
# %autoreload 2
pd.set_option('mode.chained_assignment', None)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tickers = ['RELIANCE.NS', 'TCS.NS', 'HDFCBANK.NS', 'BHARTIARTL.NS', 'ICICIBANK.NS', 'INFY.NS', 'SBIN.NS', 'HINDUNILVR.NS', 
           'BAJFINANCE.NS',
           'ITC.NS']
# '^NSEI',

# %%
# Store data in dictionary
ohlcv_dict = {}
for stock in tickers:
    ohlcv_dict[stock] = get_ohlcv(ticker=stock, period = '5y', interval='1mo')


# data = copy.deepcopy(ohlcv_dict)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
NSE = get_ohlcv(ticker='^NSEI', period = '5y', interval='1mo')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
monthly_data = copy.deepcopy(ohlcv_dict)
NSE_DATA = copy.deepcopy(NSE)

# %%
# Calculate Monthly Return

NSE_DATA['mon_rtn'] = NSE['Close'].pct_change()
NSE_DATA.tail()
# Out:
# Price              Close          High           Low          Open   Volume  \
# Ticker             ^NSEI         ^NSEI         ^NSEI         ^NSEI    ^NSEI
# Date
# 2024-10-01  24205.349609  25907.599609  24073.900391  25788.449219  6328000
# 2024-11-01  24131.099609  24537.599609  23263.150391  24302.750000  5887700
# 2024-12-01  23644.800781  24857.750000  23460.449219  24140.849609  5450800
# 2025-01-01  23508.400391  24226.699219  22786.900391  23637.650391  6458100
# 2025-02-01  22795.900391  23807.300781  22720.300781  23319.349609  4059200
#
# Price        mon_rtn
# Ticker
# Date
# 2024-10-01 -0.062203
# 2024-11-01 -0.003068
# 2024-12-01 -0.020152
# 2025-01-01 -0.005769
# 2025-02-01 -0.030308

# %%
def CAGR(data):
    # data = data.copy()
    n = len(data)/12
    data['cum_rtn'] = (1+ data['mon_rtn']).cumprod()
    data['CAGR'] =((data['cum_rtn'].iloc[-1]))**(1/n)-1
    return data
    
# Volatility

def volatility(data):
    data['VOL']  = (data['d_rtn'].std()* np.sqrt(12))
    return data

# %%
cummulative_returns(NSE_DATA)
# Out:
# Price              Close          High           Low          Open    Volume  \
# Ticker             ^NSEI         ^NSEI         ^NSEI         ^NSEI     ^NSEI
# Date
# 2020-03-01   8597.750000  11433.000000   7511.100098  11387.349609  21303000
# 2020-04-01   9859.900391   9889.049805   8055.799805   8584.099609  12736300
# 2020-05-01   9580.299805   9598.849609   8806.750000   9533.500000  13675900
# 2020-06-01  10302.099609  10553.150391   9544.349609   9726.849609  16778800
# 2020-07-01  11073.450195  11341.400391  10299.599609  10323.799805  14640200
# 2020-08-01  11387.500000  11794.250000  10882.250000  11057.549805  14035500
# 2020-09-01  11247.549805  11618.099609  10790.200195  11464.299805  12928400
# 2020-10-01  11642.400391  12025.450195  11347.049805  11364.450195  11602500
# 2020-11-01  12968.950195  13145.849609  11557.400391  11697.349609  13004600
# 2020-12-01  13981.750000  14024.849609  12962.799805  13062.200195  12077600
# 2021-01-01  13634.599609  14753.549805  13596.750000  13996.099609  13119900
# 2021-02-01  14529.150391  15431.750000  13661.750000  13758.599609  14313900
# 2021-03-01  14690.700195  15336.299805  14264.400391  14702.500000   9886800
# 2021-04-01  14631.099609  15044.349609  14151.400391  14798.400391   9344700
# 2021-05-01  15582.799805  15606.349609  14416.250000  14481.049805   9859900
# 2021-06-01  15721.500000  15915.650391  15450.900391  15629.650391   8079100
# 2021-07-01  15763.049805  15962.250000  15513.450195  15755.049805   5756800
# 2021-08-01  17132.199219  17153.500000  15834.650391  15874.900391   6349900
# 2021-09-01  17618.150391  17947.650391  17055.050781  17185.599609   6955600
# 2021-10-01  17671.650391  18604.449219  17452.900391  17531.900391   7651200
# 2021-11-01  16983.199219  18210.150391  16782.400391  17783.150391   5853100
# 2021-12-01  17354.050781  17639.500000  16410.199219  17104.400391   5499300
# 2022-01-01  17339.849609  18350.949219  16836.800781  17387.150391   5435500
# 2022-02-01  16793.900391  17794.599609  16203.250000  17529.449219   5620100
# 2022-03-01  17464.750000  17559.800781  15671.450195  16593.099609   7959500
# 2022-04-01  17102.550781  18114.650391  16824.699219  17436.900391   5658100
# 2022-05-01  16584.550781  17132.849609  15735.750000  16924.449219   6343200
# 2022-06-01  15780.250000  16793.849609  15183.400391  16594.400391   5514100
# 2022-07-01  17158.250000  17172.800781  15511.049805  15703.700195   5475300
# 2022-08-01  17759.300781  17992.199219  17154.800781  17243.199219   5589500
# 2022-09-01  17094.349609  18096.150391  16747.699219  17485.699219   6896300
# 2022-10-01  18012.199219  18022.800781  16855.550781  17102.099609   4539900
# 2022-11-01  18758.349609  18816.050781  17959.199219  18130.699219   5257200
# 2022-12-01  18105.300781  18887.599609  17774.250000  18871.949219   4741600
# 2023-01-01  17662.150391  18251.949219  17405.550781  18131.699219   5632700
# 2023-02-01  17303.949219  18134.750000  17255.199219  17811.599609   5685600
# 2023-03-01  17359.750000  17799.949219  16828.349609  17360.099609   5622200
# 2023-04-01  18065.000000  18089.150391  17312.750000  17427.949219   4459800
# 2023-05-01  18534.400391  18662.449219  18042.400391  18124.800781   5737500
# 2023-06-01  19189.050781  19201.699219  18464.550781  18579.400391   5144400
# 2023-07-01  19753.800781  19991.849609  19234.400391  19246.500000   5802500
# 2023-08-01  19253.800781  19795.599609  19223.650391  19784.000000   6027500
# 2023-09-01  19638.300781  20222.449219  19255.699219  19258.150391   5666500
# 2023-10-01  19079.599609  19849.750000  18837.849609  19622.400391   4248400
# 2023-11-01  20133.150391  20158.699219  18973.699219  19064.050781   4386100
# 2023-12-01  21731.400391  21801.449219  20183.699219  20194.099609   6121400
# 2024-01-01  21725.699219  22124.150391  21137.199219  21727.750000   6824400
# 2024-02-01  21982.800781  22297.500000  21530.199219  21780.650391   6728200
# 2024-03-01  22326.900391  22526.599609  21710.199219  22048.300781   6700100
# 2024-04-01  22604.849609  22783.349609  21777.650391  22455.000000   6034000
# 2024-05-01  22530.699219  23110.800781  21821.050781  22567.849609   6691400
# 2024-06-01  24010.599609  24174.000000  21281.449219  23337.900391   7751100
# 2024-07-01  24951.150391  24999.750000  23992.699219  23992.949219   6250600
# 2024-08-01  25235.900391  25268.349609  23893.699219  25030.949219   6327000
# 2024-09-01  25810.849609  26277.349609  24753.150391  25333.599609   6162500
# 2024-10-01  24205.349609  25907.599609  24073.900391  25788.449219   6328000
# 2024-11-01  24131.099609  24537.599609  23263.150391  24302.750000   5887700
# 2024-12-01  23644.800781  24857.750000  23460.449219  24140.849609   5450800
# 2025-01-01  23508.400391  24226.699219  22786.900391  23637.650391   6458100
# 2025-02-01  22795.900391  23807.300781  22720.300781  23319.349609   4059200
#
# Price        mon_rtn     d_rtn daily_returns   cum_rtn
# Ticker
# Date
# 2020-03-01       NaN       NaN           NaN       NaN
# 2020-04-01  0.146800  0.146800      0.146800  1.146800
# 2020-05-01 -0.028357 -0.028357     -0.028357  1.114280
# 2020-06-01  0.075342  0.075342      0.075342  1.198232
# 2020-07-01  0.074873  0.074873      0.074873  1.287947
# 2020-08-01  0.028361  0.028361      0.028361  1.324474
# 2020-09-01 -0.012290 -0.012290     -0.012290  1.308197
# 2020-10-01  0.035105  0.035105      0.035105  1.354122
# 2020-11-01  0.113941  0.113941      0.113941  1.508412
# 2020-12-01  0.078094  0.078094      0.078094  1.626210
# 2021-01-01 -0.024829 -0.024829     -0.024829  1.585833
# 2021-02-01  0.065609  0.065609      0.065609  1.689878
# 2021-03-01  0.011119  0.011119      0.011119  1.708668
# 2021-04-01 -0.004057 -0.004057     -0.004057  1.701736
# 2021-05-01  0.065046  0.065046      0.065046  1.812428
# 2021-06-01  0.008901  0.008901      0.008901  1.828560
# 2021-07-01  0.002643  0.002643      0.002643  1.833392
# 2021-08-01  0.086858  0.086858      0.086858  1.992638
# 2021-09-01  0.028365  0.028365      0.028365  2.049158
# 2021-10-01  0.003037  0.003037      0.003037  2.055381
# 2021-11-01 -0.038958 -0.038958     -0.038958  1.975307
# 2021-12-01  0.021836  0.021836      0.021836  2.018441
# 2022-01-01 -0.000818 -0.000818     -0.000818  2.016789
# 2022-02-01 -0.031485 -0.031485     -0.031485  1.953290
# 2022-03-01  0.039946  0.039946      0.039946  2.031316
# 2022-04-01 -0.020739 -0.020739     -0.020739  1.989189
# 2022-05-01 -0.030288 -0.030288     -0.030288  1.928941
# 2022-06-01 -0.048497 -0.048497     -0.048497  1.835393
# 2022-07-01  0.087324  0.087324      0.087324  1.995667
# 2022-08-01  0.035030  0.035030      0.035030  2.065575
# 2022-09-01 -0.037442 -0.037442     -0.037442  1.988235
# 2022-10-01  0.053693  0.053693      0.053693  2.094990
# 2022-11-01  0.041425  0.041425      0.041425  2.181774
# 2022-12-01 -0.034814 -0.034814     -0.034814  2.105818
# 2023-01-01 -0.024476 -0.024476     -0.024476  2.054276
# 2023-02-01 -0.020281 -0.020281     -0.020281  2.012614
# 2023-03-01  0.003225  0.003225      0.003225  2.019104
# 2023-04-01  0.040626  0.040626      0.040626  2.101131
# 2023-05-01  0.025984  0.025984      0.025984  2.155727
# 2023-06-01  0.035321  0.035321      0.035321  2.231869
# 2023-07-01  0.029431  0.029431      0.029431  2.297555
# 2023-08-01 -0.025312 -0.025312     -0.025312  2.239400
# 2023-09-01  0.019970  0.019970      0.019970  2.284121
# 2023-10-01 -0.028450 -0.028450     -0.028450  2.219139
# 2023-11-01  0.055219  0.055219      0.055219  2.341677
# 2023-12-01  0.079384  0.079384      0.079384  2.527568
# 2024-01-01 -0.000262 -0.000262     -0.000262  2.526905
# 2024-02-01  0.011834  0.011834      0.011834  2.556809
# 2024-03-01  0.015653  0.015653      0.015653  2.596831
# 2024-04-01  0.012449  0.012449      0.012449  2.629159
# 2024-05-01 -0.003280 -0.003280     -0.003280  2.620534
# 2024-06-01  0.065684  0.065684      0.065684  2.792661
# 2024-07-01  0.039172  0.039172      0.039172  2.902056
# 2024-08-01  0.011412  0.011412      0.011412  2.935175
# 2024-09-01  0.022783  0.022783      0.022783  3.002047
# 2024-10-01 -0.062203 -0.062203     -0.062203  2.815312
# 2024-11-01 -0.003068 -0.003068     -0.003068  2.806676
# 2024-12-01 -0.020152 -0.020152     -0.020152  2.750115
# 2025-01-01 -0.005769 -0.005769     -0.005769  2.734250
# 2025-02-01 -0.030308 -0.030308     -0.030308  2.651380

# %%
CAGR(NSE_DATA)
# Out:
# Price              Close          High           Low          Open    Volume  \
# Ticker             ^NSEI         ^NSEI         ^NSEI         ^NSEI     ^NSEI
# Date
# 2020-03-01   8597.750000  11433.000000   7511.100098  11387.349609  21303000
# 2020-04-01   9859.900391   9889.049805   8055.799805   8584.099609  12736300
# 2020-05-01   9580.299805   9598.849609   8806.750000   9533.500000  13675900
# 2020-06-01  10302.099609  10553.150391   9544.349609   9726.849609  16778800
# 2020-07-01  11073.450195  11341.400391  10299.599609  10323.799805  14640200
# 2020-08-01  11387.500000  11794.250000  10882.250000  11057.549805  14035500
# 2020-09-01  11247.549805  11618.099609  10790.200195  11464.299805  12928400
# 2020-10-01  11642.400391  12025.450195  11347.049805  11364.450195  11602500
# 2020-11-01  12968.950195  13145.849609  11557.400391  11697.349609  13004600
# 2020-12-01  13981.750000  14024.849609  12962.799805  13062.200195  12077600
# 2021-01-01  13634.599609  14753.549805  13596.750000  13996.099609  13119900
# 2021-02-01  14529.150391  15431.750000  13661.750000  13758.599609  14313900
# 2021-03-01  14690.700195  15336.299805  14264.400391  14702.500000   9886800
# 2021-04-01  14631.099609  15044.349609  14151.400391  14798.400391   9344700
# 2021-05-01  15582.799805  15606.349609  14416.250000  14481.049805   9859900
# 2021-06-01  15721.500000  15915.650391  15450.900391  15629.650391   8079100
# 2021-07-01  15763.049805  15962.250000  15513.450195  15755.049805   5756800
# 2021-08-01  17132.199219  17153.500000  15834.650391  15874.900391   6349900
# 2021-09-01  17618.150391  17947.650391  17055.050781  17185.599609   6955600
# 2021-10-01  17671.650391  18604.449219  17452.900391  17531.900391   7651200
# 2021-11-01  16983.199219  18210.150391  16782.400391  17783.150391   5853100
# 2021-12-01  17354.050781  17639.500000  16410.199219  17104.400391   5499300
# 2022-01-01  17339.849609  18350.949219  16836.800781  17387.150391   5435500
# 2022-02-01  16793.900391  17794.599609  16203.250000  17529.449219   5620100
# 2022-03-01  17464.750000  17559.800781  15671.450195  16593.099609   7959500
# 2022-04-01  17102.550781  18114.650391  16824.699219  17436.900391   5658100
# 2022-05-01  16584.550781  17132.849609  15735.750000  16924.449219   6343200
# 2022-06-01  15780.250000  16793.849609  15183.400391  16594.400391   5514100
# 2022-07-01  17158.250000  17172.800781  15511.049805  15703.700195   5475300
# 2022-08-01  17759.300781  17992.199219  17154.800781  17243.199219   5589500
# 2022-09-01  17094.349609  18096.150391  16747.699219  17485.699219   6896300
# 2022-10-01  18012.199219  18022.800781  16855.550781  17102.099609   4539900
# 2022-11-01  18758.349609  18816.050781  17959.199219  18130.699219   5257200
# 2022-12-01  18105.300781  18887.599609  17774.250000  18871.949219   4741600
# 2023-01-01  17662.150391  18251.949219  17405.550781  18131.699219   5632700
# 2023-02-01  17303.949219  18134.750000  17255.199219  17811.599609   5685600
# 2023-03-01  17359.750000  17799.949219  16828.349609  17360.099609   5622200
# 2023-04-01  18065.000000  18089.150391  17312.750000  17427.949219   4459800
# 2023-05-01  18534.400391  18662.449219  18042.400391  18124.800781   5737500
# 2023-06-01  19189.050781  19201.699219  18464.550781  18579.400391   5144400
# 2023-07-01  19753.800781  19991.849609  19234.400391  19246.500000   5802500
# 2023-08-01  19253.800781  19795.599609  19223.650391  19784.000000   6027500
# 2023-09-01  19638.300781  20222.449219  19255.699219  19258.150391   5666500
# 2023-10-01  19079.599609  19849.750000  18837.849609  19622.400391   4248400
# 2023-11-01  20133.150391  20158.699219  18973.699219  19064.050781   4386100
# 2023-12-01  21731.400391  21801.449219  20183.699219  20194.099609   6121400
# 2024-01-01  21725.699219  22124.150391  21137.199219  21727.750000   6824400
# 2024-02-01  21982.800781  22297.500000  21530.199219  21780.650391   6728200
# 2024-03-01  22326.900391  22526.599609  21710.199219  22048.300781   6700100
# 2024-04-01  22604.849609  22783.349609  21777.650391  22455.000000   6034000
# 2024-05-01  22530.699219  23110.800781  21821.050781  22567.849609   6691400
# 2024-06-01  24010.599609  24174.000000  21281.449219  23337.900391   7751100
# 2024-07-01  24951.150391  24999.750000  23992.699219  23992.949219   6250600
# 2024-08-01  25235.900391  25268.349609  23893.699219  25030.949219   6327000
# 2024-09-01  25810.849609  26277.349609  24753.150391  25333.599609   6162500
# 2024-10-01  24205.349609  25907.599609  24073.900391  25788.449219   6328000
# 2024-11-01  24131.099609  24537.599609  23263.150391  24302.750000   5887700
# 2024-12-01  23644.800781  24857.750000  23460.449219  24140.849609   5450800
# 2025-01-01  23508.400391  24226.699219  22786.900391  23637.650391   6458100
# 2025-02-01  22795.900391  23807.300781  22720.300781  23319.349609   4059200
#
# Price        mon_rtn     d_rtn daily_returns   cum_rtn     CAGR
# Ticker
# Date
# 2020-03-01       NaN       NaN           NaN       NaN  0.21533
# 2020-04-01  0.146800  0.146800      0.146800  1.146800  0.21533
# 2020-05-01 -0.028357 -0.028357     -0.028357  1.114280  0.21533
# 2020-06-01  0.075342  0.075342      0.075342  1.198232  0.21533
# 2020-07-01  0.074873  0.074873      0.074873  1.287947  0.21533
# 2020-08-01  0.028361  0.028361      0.028361  1.324474  0.21533
# 2020-09-01 -0.012290 -0.012290     -0.012290  1.308197  0.21533
# 2020-10-01  0.035105  0.035105      0.035105  1.354122  0.21533
# 2020-11-01  0.113941  0.113941      0.113941  1.508412  0.21533
# 2020-12-01  0.078094  0.078094      0.078094  1.626210  0.21533
# 2021-01-01 -0.024829 -0.024829     -0.024829  1.585833  0.21533
# 2021-02-01  0.065609  0.065609      0.065609  1.689878  0.21533
# 2021-03-01  0.011119  0.011119      0.011119  1.708668  0.21533
# 2021-04-01 -0.004057 -0.004057     -0.004057  1.701736  0.21533
# 2021-05-01  0.065046  0.065046      0.065046  1.812428  0.21533
# 2021-06-01  0.008901  0.008901      0.008901  1.828560  0.21533
# 2021-07-01  0.002643  0.002643      0.002643  1.833392  0.21533
# 2021-08-01  0.086858  0.086858      0.086858  1.992638  0.21533
# 2021-09-01  0.028365  0.028365      0.028365  2.049158  0.21533
# 2021-10-01  0.003037  0.003037      0.003037  2.055381  0.21533
# 2021-11-01 -0.038958 -0.038958     -0.038958  1.975307  0.21533
# 2021-12-01  0.021836  0.021836      0.021836  2.018441  0.21533
# 2022-01-01 -0.000818 -0.000818     -0.000818  2.016789  0.21533
# 2022-02-01 -0.031485 -0.031485     -0.031485  1.953290  0.21533
# 2022-03-01  0.039946  0.039946      0.039946  2.031316  0.21533
# 2022-04-01 -0.020739 -0.020739     -0.020739  1.989189  0.21533
# 2022-05-01 -0.030288 -0.030288     -0.030288  1.928941  0.21533
# 2022-06-01 -0.048497 -0.048497     -0.048497  1.835393  0.21533
# 2022-07-01  0.087324  0.087324      0.087324  1.995667  0.21533
# 2022-08-01  0.035030  0.035030      0.035030  2.065575  0.21533
# 2022-09-01 -0.037442 -0.037442     -0.037442  1.988235  0.21533
# 2022-10-01  0.053693  0.053693      0.053693  2.094990  0.21533
# 2022-11-01  0.041425  0.041425      0.041425  2.181774  0.21533
# 2022-12-01 -0.034814 -0.034814     -0.034814  2.105818  0.21533
# 2023-01-01 -0.024476 -0.024476     -0.024476  2.054276  0.21533
# 2023-02-01 -0.020281 -0.020281     -0.020281  2.012614  0.21533
# 2023-03-01  0.003225  0.003225      0.003225  2.019104  0.21533
# 2023-04-01  0.040626  0.040626      0.040626  2.101131  0.21533
# 2023-05-01  0.025984  0.025984      0.025984  2.155727  0.21533
# 2023-06-01  0.035321  0.035321      0.035321  2.231869  0.21533
# 2023-07-01  0.029431  0.029431      0.029431  2.297555  0.21533
# 2023-08-01 -0.025312 -0.025312     -0.025312  2.239400  0.21533
# 2023-09-01  0.019970  0.019970      0.019970  2.284121  0.21533
# 2023-10-01 -0.028450 -0.028450     -0.028450  2.219139  0.21533
# 2023-11-01  0.055219  0.055219      0.055219  2.341677  0.21533
# 2023-12-01  0.079384  0.079384      0.079384  2.527568  0.21533
# 2024-01-01 -0.000262 -0.000262     -0.000262  2.526905  0.21533
# 2024-02-01  0.011834  0.011834      0.011834  2.556809  0.21533
# 2024-03-01  0.015653  0.015653      0.015653  2.596831  0.21533
# 2024-04-01  0.012449  0.012449      0.012449  2.629159  0.21533
# 2024-05-01 -0.003280 -0.003280     -0.003280  2.620534  0.21533
# 2024-06-01  0.065684  0.065684      0.065684  2.792661  0.21533
# 2024-07-01  0.039172  0.039172      0.039172  2.902056  0.21533
# 2024-08-01  0.011412  0.011412      0.011412  2.935175  0.21533
# 2024-09-01  0.022783  0.022783      0.022783  3.002047  0.21533
# 2024-10-01 -0.062203 -0.062203     -0.062203  2.815312  0.21533
# 2024-11-01 -0.003068 -0.003068     -0.003068  2.806676  0.21533
# 2024-12-01 -0.020152 -0.020152     -0.020152  2.750115  0.21533
# 2025-01-01 -0.005769 -0.005769     -0.005769  2.734250  0.21533
# 2025-02-01 -0.030308 -0.030308     -0.030308  2.651380  0.21533

# %%
# Download monthly data for all tickers and make deepcoopy and calculate monthly return and CAGR
return_df = pd.DataFrame()

for stock in monthly_data.keys():
    print(f"Calculate the monthly return of {stock}")
    monthly_data[stock]['mon_rtn'] = monthly_data[stock]['Close'].pct_change()
    return_df[stock] = monthly_data[stock]['mon_rtn']
# Out:
# Calculate the monthly return of RELIANCE.NS
# Calculate the monthly return of TCS.NS
# Calculate the monthly return of HDFCBANK.NS
# Calculate the monthly return of BHARTIARTL.NS
# Calculate the monthly return of ICICIBANK.NS
# Calculate the monthly return of INFY.NS
# Calculate the monthly return of SBIN.NS
# Calculate the monthly return of HINDUNILVR.NS
# Calculate the monthly return of BAJFINANCE.NS
# Calculate the monthly return of ITC.NS

# %%
return_df
# Out:
#             RELIANCE.NS    TCS.NS  HDFCBANK.NS  BHARTIARTL.NS  ICICIBANK.NS  \
# Date
# 2020-03-01          NaN       NaN          NaN            NaN           NaN
# 2020-04-01     0.316274  0.111203     0.162316       0.166478      0.174208
# 2020-05-01     0.008377 -0.020899    -0.050060       0.074470     -0.126792
# 2020-06-01     0.163685  0.055670     0.120002       0.013120      0.058744
# 2020-07-01     0.213016  0.098915    -0.031008      -0.008931     -0.013231
# 2020-08-01     0.014805 -0.008366     0.080412      -0.075246      0.137832
# 2020-09-01     0.073845  0.104131    -0.033383      -0.176649     -0.100988
# 2020-10-01    -0.080493  0.069233     0.097302       0.030407      0.106695
# 2020-11-01    -0.060696  0.009841     0.217397       0.068012      0.205680
# 2020-12-01     0.028759  0.068330    -0.003158       0.100270      0.130347
# 2021-01-01    -0.072206  0.086840    -0.031888       0.086129      0.003644
# 2021-02-01     0.132387 -0.067991     0.103488       0.004877      0.113129
# 2021-03-01    -0.039649  0.097969    -0.026558      -0.070106     -0.026182
# 2021-04-01    -0.004293 -0.044747    -0.054464       0.037599      0.031610
# 2021-05-01     0.083129  0.040683     0.073320      -0.003447      0.103663
# 2021-06-01    -0.022983  0.064247    -0.011841      -0.017293     -0.048057
# 2021-07-01    -0.032338 -0.053292    -0.043579       0.068487      0.081788
# 2021-08-01     0.109492  0.198034     0.108626       0.182320      0.056638
# 2021-09-01     0.115626 -0.002879     0.008568       0.055979     -0.025311
# 2021-10-01     0.006748 -0.100065    -0.007586      -0.004286      0.144396
# 2021-11-01    -0.051592  0.040666    -0.056417       0.062596     -0.109345
# 2021-12-01    -0.015486  0.059278    -0.009474      -0.061037      0.036117
# 2022-01-01     0.007791 -0.000562     0.004258       0.066540      0.065730
# 2022-02-01    -0.011334 -0.047054    -0.040015      -0.058686     -0.058443
# 2022-03-01     0.116632  0.052262     0.030920       0.099709     -0.016696
# 2022-04-01     0.059019 -0.051672    -0.058319      -0.021127      0.017801
# 2022-05-01    -0.056482 -0.051414     0.003142      -0.052503      0.012848
# 2022-06-01    -0.014054 -0.022365    -0.018198      -0.021780     -0.060636
# 2022-07-01    -0.033209  0.010652     0.063946      -0.010220      0.157523
# 2022-08-01     0.051206 -0.024917     0.036187       0.071760      0.083924
# 2022-09-01    -0.092736 -0.064338    -0.043570       0.105774     -0.022684
# 2022-10-01     0.072274  0.062771     0.053013       0.040130      0.054176
# 2022-11-01     0.071286  0.064646     0.074664       0.020132      0.048641
# 2022-12-01    -0.067421 -0.039548     0.012248      -0.050250     -0.065117
# 2023-01-01    -0.075907  0.031320    -0.015140      -0.044411     -0.066173
# 2023-02-01    -0.013297 -0.011307    -0.002432      -0.036414      0.027587
# 2023-03-01     0.003660 -0.032284     0.006220       0.009094      0.026203
# 2023-04-01     0.038373  0.004164     0.048492       0.067156      0.046053
# 2023-05-01     0.020409  0.021822    -0.045479       0.063306      0.034327
# 2023-06-01     0.032532  0.003876     0.068325       0.033945     -0.015330
# 2023-07-01     0.082999  0.043802    -0.029505       0.012689      0.068158
# 2023-08-01    -0.055801 -0.016344    -0.048298      -0.037645     -0.039617
# 2023-09-01    -0.018851  0.051180    -0.028731       0.086706      0.009304
# 2023-10-01    -0.024350 -0.045301    -0.032628      -0.012953     -0.038397
# 2023-11-01     0.039141  0.037959     0.055740       0.109689      0.021413
# 2023-12-01     0.087278  0.087682     0.096517       0.017246      0.065939
# 2024-01-01     0.103793  0.005945    -0.144332       0.134179      0.031658
# 2024-02-01     0.023955  0.078126    -0.040443      -0.040446      0.023391
# 2024-03-01     0.017148 -0.053430     0.031709       0.093693      0.039061
# 2024-04-01    -0.012686 -0.014356     0.049865       0.076266      0.052227
# 2024-05-01    -0.024949 -0.039182     0.007532       0.038153     -0.025513
# 2024-06-01     0.094379  0.071256     0.114422       0.051940      0.070068
# 2024-07-01    -0.038313  0.123253    -0.040415       0.032894      0.012754
# 2024-08-01     0.002790  0.040812     0.013090       0.065368      0.011770
# 2024-09-01    -0.015231 -0.062641     0.058128       0.081827      0.044548
# 2024-10-01    -0.097878 -0.070294     0.002107      -0.056711      0.015122
# 2024-11-01    -0.029916  0.078827     0.034770       0.009023      0.006075
# 2024-12-01    -0.059395 -0.041221    -0.012917      -0.024214     -0.014191
# 2025-01-01     0.040849  0.004298    -0.041797       0.024280     -0.022510
# 2025-02-01    -0.030195 -0.063731    -0.005151       0.006426     -0.016603
#
#              INFY.NS   SBIN.NS  HINDUNILVR.NS  BAJFINANCE.NS    ITC.NS
# Date
# 2020-03-01       NaN       NaN            NaN            NaN       NaN
# 2020-04-01  0.115355 -0.032258      -0.045029       0.048573  0.060279
# 2020-05-01 -0.034242 -0.153281      -0.062711      -0.157219  0.084043
# 2020-06-01  0.079548  0.106324       0.059615       0.449083 -0.013681
# 2020-07-01  0.312589  0.072849       0.020634       0.148463 -0.002569
# 2020-08-01 -0.038716  0.107339      -0.037783       0.072740  0.034901
# 2020-09-01  0.085774 -0.125472      -0.023190      -0.059981 -0.101518
# 2020-10-01  0.051922  0.020766       0.001475       0.009272 -0.037565
# 2020-11-01  0.048290  0.290621       0.038981       0.483469  0.171861
# 2020-12-01  0.141636  0.125691       0.120288       0.078716  0.079267
# 2021-01-01 -0.013338  0.026005      -0.054897      -0.105879 -0.027512
# 2021-02-01  0.011501  0.383020      -0.058240       0.112017  0.002952
# 2021-03-01  0.091558 -0.066257       0.140451      -0.021852  0.097272
# 2021-04-01 -0.010014 -0.029646      -0.031976       0.058652 -0.072769
# 2021-05-01  0.029092  0.200425      -0.005821       0.032292  0.069102
# 2021-06-01  0.146445 -0.012136       0.056089       0.068924 -0.064174
# 2021-07-01  0.018788  0.039567      -0.049009       0.035282  0.039220
# 2021-08-01  0.059578 -0.013316       0.167488       0.210106  0.030983
# 2021-09-01 -0.018313  0.063256      -0.008186       0.019084  0.117605
# 2021-10-01 -0.004447  0.108499      -0.114239      -0.034937 -0.054838
# 2021-11-01  0.036024 -0.082844      -0.025639      -0.054451 -0.009185
# 2021-12-01  0.102239 -0.000217       0.018382      -0.002851 -0.014018
# 2022-01-01 -0.080281  0.169074      -0.036608       0.003289  0.009860
# 2022-02-01 -0.011865 -0.102359      -0.044706       0.000293 -0.019755
# 2022-03-01  0.111477  0.021420      -0.056834       0.036795  0.188056
# 2022-04-01 -0.177937  0.005572       0.090889      -0.081013  0.035508
# 2022-05-01 -0.040796 -0.056820       0.052979      -0.088379  0.042766
# 2022-06-01 -0.017437  0.010833      -0.052119      -0.112074  0.034234
# 2022-07-01  0.060059  0.134042       0.192812       0.339755  0.108044
# 2022-08-01 -0.036620  0.005489       0.008512       0.013476  0.057581
# 2022-09-01 -0.053250 -0.001224       0.013760       0.004038  0.036506
# 2022-10-01  0.087870  0.081417      -0.054053      -0.026125  0.049669
# 2022-11-01  0.074898  0.049930       0.052397      -0.059231 -0.024950
# 2022-12-01 -0.077525  0.018674      -0.039532      -0.021686 -0.024853
# 2023-01-01  0.016941 -0.098094       0.006130      -0.104757  0.062736
# 2023-02-01 -0.030122 -0.055465      -0.045057       0.038343  0.069107
# 2023-03-01 -0.040066  0.001817       0.040518      -0.081044  0.034107
# 2023-04-01 -0.122693  0.104153      -0.040248       0.118102  0.109648
# 2023-05-01  0.052325  0.002680       0.085561       0.113016  0.046881
# 2023-06-01  0.013047  0.007126       0.003974       0.024428  0.029161
# 2023-07-01  0.028770  0.082657      -0.036008       0.023842  0.031222
# 2023-08-01  0.058826 -0.094889      -0.021770      -0.018807 -0.055830
# 2023-09-01  0.000000  0.066269      -0.015748       0.090430  0.010689
# 2023-10-01 -0.046710 -0.055133       0.007462      -0.040726 -0.036004
# 2023-11-01  0.077159 -0.001415       0.024779      -0.049482  0.017274
# 2023-12-01  0.060303  0.136875       0.054188       0.028904  0.060349
# 2024-01-01  0.076479 -0.002414      -0.068470      -0.063437 -0.044471
# 2024-02-01  0.007827  0.167994      -0.027906      -0.053556 -0.079832
# 2024-03-01 -0.105054  0.005681      -0.061331       0.115452  0.069754
# 2024-04-01 -0.051734  0.098226      -0.014971      -0.044402  0.017042
# 2024-05-01 -0.009609  0.004962       0.044206      -0.032621 -0.021118
# 2024-06-01  0.129443  0.039546       0.061828       0.062387 -0.003635
# 2024-07-01  0.192437  0.027622       0.104713      -0.038567  0.186481
# 2024-08-01  0.040385 -0.065108       0.026740       0.057764  0.013223
# 2024-09-01 -0.035036 -0.033963       0.064903       0.069839  0.032377
# 2024-10-01 -0.063100  0.040995      -0.145371      -0.105576 -0.056644
# 2024-11-01  0.069287  0.022860      -0.012697      -0.045553 -0.024652
# 2024-12-01  0.011922 -0.052447      -0.064112       0.037577  0.014473
# 2025-01-01 -0.000106 -0.027738       0.061005       0.155665 -0.074744
# 2025-02-01 -0.034472 -0.067991      -0.093284       0.063652 -0.090447

# %%
DF = return_df.copy()
portfolio = ['RELIANCE.NS', 'TCS.NS', 'HDFCBANK.NS', 'BHARTIARTL.NS', 'ICICIBANK.NS', 'INFY.NS']
mon_return = [0]
stock_to_keep = 6
filter_stock_monthly = 3

# %%
def pflio(DF, stock_to_keep, filter_stock_monthly):
    df = DF.copy()
    portfolio = []
    mon_return = [0]
    for i in range(1, len(df)):
        if len(portfolio)> 0:
            mon_return.append(DF[portfolio].iloc[i,:].mean())
            # print(f"monthluy return is {mon_return}")
            bad_stocks = df[portfolio].iloc[-1,:].sort_values(ascending = True)[:filter_stock_monthly].index.values.tolist()
            # print(f"bad stick are : {bad_stocks}")
            portfolio = [t for t in portfolio if t not in bad_stocks]
            # print(f"before new add + {portfolio}")
        fill = stock_to_keep - len(portfolio)
        # print(f"to fill is {fill}")
        new_pick  = df.iloc[i,:].sort_values(ascending = False)[:fill].index.values.tolist()
        # new_pick  = df[[t for t in tickers if t not in portfolio]].iloc[i,:].sort_values(ascending = False)[:fill].index.values.tolist()
        # print(f"new pick are {new_pick}")
        portfolio = new_pick + portfolio
        print(f"New portoflio is : {portfolio}")
        print('---')
    mon_return_df = pd.DataFrame(np.array(mon_return), columns=['mon_ret'])
    return mon_return_df

# %%
result = pflio(DF, 6, 3)
# Out:
# New portoflio is : ['RELIANCE.NS', 'ICICIBANK.NS', 'BHARTIARTL.NS', 'HDFCBANK.NS', 'INFY.NS', 'TCS.NS']
# ---
# New portoflio is : ['ITC.NS', 'BHARTIARTL.NS', 'RELIANCE.NS', 'ICICIBANK.NS', 'BHARTIARTL.NS', 'HDFCBANK.NS']
# ---
# New portoflio is : ['BAJFINANCE.NS', 'RELIANCE.NS', 'HDFCBANK.NS', 'BHARTIARTL.NS', 'BHARTIARTL.NS', 'HDFCBANK.NS']
# ---
# New portoflio is : ['INFY.NS', 'RELIANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BHARTIARTL.NS', 'BHARTIARTL.NS']
# ---
# New portoflio is : ['ICICIBANK.NS', 'SBIN.NS', 'HDFCBANK.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['TCS.NS', 'INFY.NS', 'RELIANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['ICICIBANK.NS', 'HDFCBANK.NS', 'TCS.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['BAJFINANCE.NS', 'SBIN.NS', 'HDFCBANK.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['INFY.NS', 'ICICIBANK.NS', 'SBIN.NS', 'HINDUNILVR.NS', 'BHARTIARTL.NS', 'ITC.NS']
# ---
# New portoflio is : ['TCS.NS', 'BHARTIARTL.NS', 'SBIN.NS', 'INFY.NS', 'ICICIBANK.NS', 'BHARTIARTL.NS']
# ---
# New portoflio is : ['SBIN.NS', 'RELIANCE.NS', 'ICICIBANK.NS', 'BHARTIARTL.NS', 'ICICIBANK.NS', 'BHARTIARTL.NS']
# ---
# New portoflio is : ['HINDUNILVR.NS', 'TCS.NS', 'ITC.NS', 'INFY.NS', 'BHARTIARTL.NS', 'BHARTIARTL.NS']
# ---
# New portoflio is : ['BAJFINANCE.NS', 'BHARTIARTL.NS', 'ICICIBANK.NS', 'INFY.NS', 'BHARTIARTL.NS', 'BHARTIARTL.NS']
# ---
# New portoflio is : ['SBIN.NS', 'ICICIBANK.NS', 'RELIANCE.NS', 'HDFCBANK.NS', 'ITC.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['INFY.NS', 'BAJFINANCE.NS', 'TCS.NS', 'ICICIBANK.NS', 'HDFCBANK.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['ICICIBANK.NS', 'BHARTIARTL.NS', 'SBIN.NS', 'BAJFINANCE.NS', 'HDFCBANK.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['BAJFINANCE.NS', 'TCS.NS', 'BHARTIARTL.NS', 'BHARTIARTL.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['ITC.NS', 'RELIANCE.NS', 'SBIN.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['ICICIBANK.NS', 'SBIN.NS', 'RELIANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['BHARTIARTL.NS', 'TCS.NS', 'INFY.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['INFY.NS', 'TCS.NS', 'ICICIBANK.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['SBIN.NS', 'BHARTIARTL.NS', 'ICICIBANK.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['BAJFINANCE.NS', 'RELIANCE.NS', 'INFY.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['ITC.NS', 'RELIANCE.NS', 'INFY.NS', 'BHARTIARTL.NS', 'TCS.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['HINDUNILVR.NS', 'RELIANCE.NS', 'ITC.NS', 'RELIANCE.NS', 'BHARTIARTL.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['HINDUNILVR.NS', 'ITC.NS', 'ICICIBANK.NS', 'HDFCBANK.NS', 'BHARTIARTL.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['ITC.NS', 'SBIN.NS', 'RELIANCE.NS', 'HDFCBANK.NS', 'BHARTIARTL.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['BAJFINANCE.NS', 'HINDUNILVR.NS', 'ICICIBANK.NS', 'HDFCBANK.NS', 'BHARTIARTL.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['ICICIBANK.NS', 'BHARTIARTL.NS', 'ITC.NS', 'BAJFINANCE.NS', 'BHARTIARTL.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['BHARTIARTL.NS', 'ITC.NS', 'HINDUNILVR.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['INFY.NS', 'SBIN.NS', 'RELIANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['INFY.NS', 'HDFCBANK.NS', 'RELIANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['SBIN.NS', 'HDFCBANK.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['ITC.NS', 'TCS.NS', 'INFY.NS', 'HINDUNILVR.NS', 'HDFCBANK.NS', 'BHARTIARTL.NS']
# ---
# New portoflio is : ['ITC.NS', 'BAJFINANCE.NS', 'ICICIBANK.NS', 'INFY.NS', 'HDFCBANK.NS', 'BHARTIARTL.NS']
# ---
# New portoflio is : ['HINDUNILVR.NS', 'ITC.NS', 'ICICIBANK.NS', 'BAJFINANCE.NS', 'HDFCBANK.NS', 'BHARTIARTL.NS']
# ---
# New portoflio is : ['BAJFINANCE.NS', 'ITC.NS', 'SBIN.NS', 'BAJFINANCE.NS', 'HDFCBANK.NS', 'BHARTIARTL.NS']
# ---
# New portoflio is : ['BAJFINANCE.NS', 'HINDUNILVR.NS', 'BHARTIARTL.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BHARTIARTL.NS']
# ---
# New portoflio is : ['HDFCBANK.NS', 'BHARTIARTL.NS', 'RELIANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['RELIANCE.NS', 'SBIN.NS', 'ICICIBANK.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['INFY.NS', 'TCS.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['BAJFINANCE.NS', 'BHARTIARTL.NS', 'SBIN.NS', 'TCS.NS', 'ITC.NS', 'ICICIBANK.NS']
# ---
# New portoflio is : ['HINDUNILVR.NS', 'BHARTIARTL.NS', 'RELIANCE.NS', 'BAJFINANCE.NS', 'BHARTIARTL.NS', 'ICICIBANK.NS']
# ---
# New portoflio is : ['BHARTIARTL.NS', 'INFY.NS', 'HDFCBANK.NS', 'BHARTIARTL.NS', 'BAJFINANCE.NS', 'BHARTIARTL.NS']
# ---
# New portoflio is : ['SBIN.NS', 'HDFCBANK.NS', 'TCS.NS', 'RELIANCE.NS', 'ICICIBANK.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['BHARTIARTL.NS', 'RELIANCE.NS', 'INFY.NS', 'HDFCBANK.NS', 'ICICIBANK.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['SBIN.NS', 'TCS.NS', 'RELIANCE.NS', 'BHARTIARTL.NS', 'HDFCBANK.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['BAJFINANCE.NS', 'BHARTIARTL.NS', 'ITC.NS', 'BHARTIARTL.NS', 'HDFCBANK.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['SBIN.NS', 'BHARTIARTL.NS', 'ICICIBANK.NS', 'HDFCBANK.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['HINDUNILVR.NS', 'BHARTIARTL.NS', 'HDFCBANK.NS', 'BHARTIARTL.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['INFY.NS', 'HDFCBANK.NS', 'RELIANCE.NS', 'TCS.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['INFY.NS', 'ITC.NS', 'TCS.NS', 'HDFCBANK.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['BHARTIARTL.NS', 'BAJFINANCE.NS', 'TCS.NS', 'HDFCBANK.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['BHARTIARTL.NS', 'BAJFINANCE.NS', 'HINDUNILVR.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---
# New portoflio is : ['SBIN.NS', 'ICICIBANK.NS', 'HDFCBANK.NS', 'ITC.NS', 'BHARTIARTL.NS', 'INFY.NS']
# ---
# New portoflio is : ['TCS.NS', 'INFY.NS', 'HDFCBANK.NS', 'ICICIBANK.NS', 'HDFCBANK.NS', 'BHARTIARTL.NS']
# ---
# New portoflio is : ['BAJFINANCE.NS', 'ITC.NS', 'INFY.NS', 'HDFCBANK.NS', 'HDFCBANK.NS', 'BHARTIARTL.NS']
# ---
# New portoflio is : ['BAJFINANCE.NS', 'HINDUNILVR.NS', 'RELIANCE.NS', 'BHARTIARTL.NS', 'BAJFINANCE.NS', 'BHARTIARTL.NS']
# ---
# New portoflio is : ['BAJFINANCE.NS', 'BHARTIARTL.NS', 'HDFCBANK.NS', 'ICICIBANK.NS', 'BAJFINANCE.NS', 'BAJFINANCE.NS']
# ---

# %%
def CAGR2(DF):
    "function to calculate the Cumulative Annual Growth Rate of a trading strategy"
    df = DF.copy()
    df["cum_return"] = (1 + df["mon_ret"]).cumprod()
    n = len(df)/12
    CAGR = (df["cum_return"].tolist()[-1])**(1/n) - 1
    return CAGR

def volatility2(DF):
    "function to calculate annualized volatility of a trading strategy"
    df = DF.copy()
    vol = df["mon_ret"].std() * np.sqrt(12)
    return vol

def sharpe2(DF,rf):
    "function to calculate sharpe ratio ; rf is the risk free rate"
    df = DF.copy()
    sr = (CAGR(df) - rf)/volatility(df)
    return sr
    

def max_dd2(DF):
    "function to calculate max drawdown"
    df = DF.copy()
    df["cum_return"] = (1 + df["mon_ret"]).cumprod()
    df["cum_roll_max"] = df["cum_return"].cummax()
    df["drawdown"] = df["cum_roll_max"] - df["cum_return"]
    df["drawdown_pct"] = df["drawdown"]/df["cum_roll_max"]
    max_dd = df["drawdown_pct"].max()
    return max_dd

# %%
CAGR2(result)
# Out:
# 0.1588037477587807

# %%
DF[portfolio].iloc[-1,:].sort_values(ascending = True)[:3].index.values.tolist()
# Out:
# ['TCS.NS', 'INFY.NS', 'RELIANCE.NS']

# %%
DF[portfolio].iloc[-1,:].sort_values().mean()
# Out:
# -0.023954279231582536

# %%
DF[portfolio].iloc[-1,:].sort_values()
# Out:
# TCS.NS          -0.063731
# INFY.NS         -0.034472
# RELIANCE.NS     -0.030195
# ICICIBANK.NS    -0.016603
# HDFCBANK.NS     -0.005151
# BHARTIARTL.NS    0.006426
# Name: 2025-02-01 00:00:00, dtype: float64
