# %%
from getData import get_data, get_ohlcv
from technical_indicator import LR, MACD, RSI, BB, ATR, ADX, RENKO
from Returns import cummulative_returns, CAGR, volatility, SHARPE, SORTINO, MAXDROWDOWN, CALMAR

import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd
import numpy as np
import datetime as dt
import copy
# %load_ext autoreload
# %autoreload 2
pd.set_option('mode.chained_assignment', None)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tickers = ['RELIANCE.NS']
           
           # 'TCS.NS', 'HDFCBANK.NS', 'BHARTIARTL.NS', 'ICICIBANK.NS', 'INFY.NS', 'SBIN.NS', 'HINDUNILVR.NS', 
           # 'BAJFINANCE.NS',
           # 'ITC.NS']
# '^NSEI',

# %%
# Store data in dictionary
ohlcv_dict = {}
for stock in tickers:
    ohlcv_dict[stock] = get_ohlcv(ticker=stock, period = '1mo', interval='5m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = copy.deepcopy(ohlcv_dict)

# %%
# Calculating ATR Roll max Roll min and Roll max for volumn

for stock in tickers:
    data[stock]['ATR'] = ATR(data[stock], 20)
    # print(data[stock].shape)
    data[stock]['roll_max_cp'] = data[stock]['High'].rolling(20).max()

    # print(data[stock].shape)
    data[stock]['roll_min_cp'] = data[stock]['Low'].rolling(20).min()
    data[stock]['roll_max_vol'] = data[stock]['Volume'].rolling(20).max()
    data[stock].dropna(inplace = True)

# %%
data['RELIANCE.NS']
# Out:
# Price                            Close         High          Low         Open  \
# Ticker                     RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS
# Datetime
# 2025-01-27 05:25:00+00:00  1220.400024  1221.050049  1220.000000  1220.699951
# 2025-01-27 05:30:00+00:00  1221.000000  1221.000000  1220.000000  1220.500000
# 2025-01-27 05:35:00+00:00  1222.550049  1222.599976  1220.349976  1220.699951
# 2025-01-27 05:40:00+00:00  1221.800049  1222.650024  1221.000000  1222.599976
# 2025-01-27 05:45:00+00:00  1222.449951  1223.000000  1221.050049  1221.800049
# ...                                ...          ...          ...          ...
# 2025-02-25 09:35:00+00:00  1203.699951  1205.849976  1202.150024  1205.650024
# 2025-02-25 09:40:00+00:00  1203.449951  1206.750000  1202.699951  1203.000000
# 2025-02-25 09:45:00+00:00  1203.849976  1204.349976  1202.650024  1203.449951
# 2025-02-25 09:50:00+00:00  1202.349976  1203.900024  1201.650024  1203.849976
# 2025-02-25 09:55:00+00:00  1202.000000  1203.000000  1201.849976  1202.500000
#
# Price                          Volume       ATR  roll_max_cp  roll_min_cp  \
# Ticker                    RELIANCE.NS
# Datetime
# 2025-01-27 05:25:00+00:00      110073  2.413360  1239.550049  1220.000000
# 2025-01-27 05:30:00+00:00      170004  2.260008  1239.550049  1220.000000
# 2025-01-27 05:35:00+00:00      124289  2.258936  1239.400024  1220.000000
# 2025-01-27 05:40:00+00:00      158954  2.194496  1237.050049  1220.000000
# 2025-01-27 05:45:00+00:00      184607  2.168888  1236.000000  1220.000000
# ...                               ...       ...          ...          ...
# 2025-02-25 09:35:00+00:00      876141  1.532631  1212.699951  1202.150024
# 2025-02-25 09:40:00+00:00      626633  1.772385  1212.699951  1202.150024
# 2025-02-25 09:45:00+00:00      663120  1.765486  1212.699951  1202.150024
# 2025-02-25 09:50:00+00:00      583933  1.811631  1212.699951  1201.650024
# 2025-02-25 09:55:00+00:00      314805  1.748620  1212.699951  1201.650024
#
# Price                     roll_max_vol
# Ticker
# Datetime
# 2025-01-27 05:25:00+00:00     313272.0
# 2025-01-27 05:30:00+00:00     313272.0
# 2025-01-27 05:35:00+00:00     313272.0
# 2025-01-27 05:40:00+00:00     313272.0
# 2025-01-27 05:45:00+00:00     313272.0
# ...                                ...
# 2025-02-25 09:35:00+00:00     876141.0
# 2025-02-25 09:40:00+00:00     876141.0
# 2025-02-25 09:45:00+00:00     876141.0
# 2025-02-25 09:50:00+00:00     876141.0
# 2025-02-25 09:55:00+00:00     876141.0
#
# [1630 rows x 9 columns]

# %%
cummulative_returns(a)
# Out:
# Price                            Close         High          Low         Open  \
# Ticker                     RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS
# Datetime
# 2025-01-27 03:45:00+00:00  1235.949951  1240.300049  1234.349976  1237.849976
# 2025-01-27 03:50:00+00:00  1236.750000  1238.300049  1234.300049  1235.750000
# 2025-01-27 03:55:00+00:00  1237.900024  1239.550049  1236.050049  1236.699951
# 2025-01-27 04:00:00+00:00  1236.550049  1239.400024  1235.050049  1237.900024
# 2025-01-27 04:05:00+00:00  1235.699951  1237.050049  1235.050049  1236.650024
# ...                                ...          ...          ...          ...
# 2025-02-25 09:35:00+00:00  1203.699951  1205.849976  1202.150024  1205.650024
# 2025-02-25 09:40:00+00:00  1203.449951  1206.750000  1202.699951  1203.000000
# 2025-02-25 09:45:00+00:00  1203.849976  1204.349976  1202.650024  1203.449951
# 2025-02-25 09:50:00+00:00  1202.349976  1203.900024  1201.650024  1203.849976
# 2025-02-25 09:55:00+00:00  1202.000000  1203.000000  1201.849976  1202.500000
#
# Price                          Volume       H-L      H-PC      L-PC        TR  \
# Ticker                    RELIANCE.NS
# Datetime
# 2025-01-27 03:45:00+00:00           0  5.950073       NaN       NaN       NaN
# 2025-01-27 03:50:00+00:00      185499  4.000000  2.350098 -1.649902  4.000000
# 2025-01-27 03:55:00+00:00      134408  3.500000  2.800049 -0.699951  3.500000
# 2025-01-27 04:00:00+00:00      220512  4.349976  1.500000 -2.849976  4.349976
# 2025-01-27 04:05:00+00:00      121827  2.000000  0.500000 -1.500000  2.000000
# ...                               ...       ...       ...       ...       ...
# 2025-02-25 09:35:00+00:00      876141  3.699951  0.349976 -3.349976  3.699951
# 2025-02-25 09:40:00+00:00      626633  4.050049  3.050049 -1.000000  4.050049
# 2025-02-25 09:45:00+00:00      663120  1.699951  0.900024 -0.799927  1.699951
# 2025-02-25 09:50:00+00:00      583933  2.250000  0.050049 -2.199951  2.250000
# 2025-02-25 09:55:00+00:00      314805  1.150024  0.650024 -0.500000  1.150024
#
# Price                           ATR     d_rtn daily_returns   cum_rtn
# Ticker
# Datetime
# 2025-01-27 03:45:00+00:00       NaN       NaN           NaN       NaN
# 2025-01-27 03:50:00+00:00       NaN  0.000647      0.000647  1.000647
# 2025-01-27 03:55:00+00:00       NaN  0.000930      0.000930  1.001578
# 2025-01-27 04:00:00+00:00       NaN -0.001091     -0.001091  1.000486
# 2025-01-27 04:05:00+00:00       NaN -0.000687     -0.000687  0.999798
# ...                             ...       ...           ...       ...
# 2025-02-25 09:35:00+00:00  1.606194 -0.001493     -0.001493  0.973907
# 2025-02-25 09:40:00+00:00  1.932042 -0.000208     -0.000208  0.973704
# 2025-02-25 09:45:00+00:00  1.901096  0.000332      0.000332  0.974028
# 2025-02-25 09:50:00+00:00  1.947617 -0.001246     -0.001246  0.972814
# 2025-02-25 09:55:00+00:00  1.841271 -0.000291     -0.000291  0.972531
#
# [1650 rows x 13 columns]

# %%
CAGR(a, n = 252*78)
# Out:
# Price                            Close         High          Low         Open  \
# Ticker                     RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS
# Datetime
# 2025-01-27 03:45:00+00:00  1235.949951  1240.300049  1234.349976  1237.849976
# 2025-01-27 03:50:00+00:00  1236.750000  1238.300049  1234.300049  1235.750000
# 2025-01-27 03:55:00+00:00  1237.900024  1239.550049  1236.050049  1236.699951
# 2025-01-27 04:00:00+00:00  1236.550049  1239.400024  1235.050049  1237.900024
# 2025-01-27 04:05:00+00:00  1235.699951  1237.050049  1235.050049  1236.650024
# ...                                ...          ...          ...          ...
# 2025-02-25 09:35:00+00:00  1203.699951  1205.849976  1202.150024  1205.650024
# 2025-02-25 09:40:00+00:00  1203.449951  1206.750000  1202.699951  1203.000000
# 2025-02-25 09:45:00+00:00  1203.849976  1204.349976  1202.650024  1203.449951
# 2025-02-25 09:50:00+00:00  1202.349976  1203.900024  1201.650024  1203.849976
# 2025-02-25 09:55:00+00:00  1202.000000  1203.000000  1201.849976  1202.500000
#
# Price                          Volume       H-L      H-PC      L-PC        TR  \
# Ticker                    RELIANCE.NS
# Datetime
# 2025-01-27 03:45:00+00:00           0  5.950073       NaN       NaN       NaN
# 2025-01-27 03:50:00+00:00      185499  4.000000  2.350098 -1.649902  4.000000
# 2025-01-27 03:55:00+00:00      134408  3.500000  2.800049 -0.699951  3.500000
# 2025-01-27 04:00:00+00:00      220512  4.349976  1.500000 -2.849976  4.349976
# 2025-01-27 04:05:00+00:00      121827  2.000000  0.500000 -1.500000  2.000000
# ...                               ...       ...       ...       ...       ...
# 2025-02-25 09:35:00+00:00      876141  3.699951  0.349976 -3.349976  3.699951
# 2025-02-25 09:40:00+00:00      626633  4.050049  3.050049 -1.000000  4.050049
# 2025-02-25 09:45:00+00:00      663120  1.699951  0.900024 -0.799927  1.699951
# 2025-02-25 09:50:00+00:00      583933  2.250000  0.050049 -2.199951  2.250000
# 2025-02-25 09:55:00+00:00      314805  1.150024  0.650024 -0.500000  1.150024
#
# Price                           ATR     d_rtn daily_returns   cum_rtn  \
# Ticker
# Datetime
# 2025-01-27 03:45:00+00:00       NaN       NaN           NaN       NaN
# 2025-01-27 03:50:00+00:00       NaN  0.000647      0.000647  1.000647
# 2025-01-27 03:55:00+00:00       NaN  0.000930      0.000930  1.001578
# 2025-01-27 04:00:00+00:00       NaN -0.001091     -0.001091  1.000486
# 2025-01-27 04:05:00+00:00       NaN -0.000687     -0.000687  0.999798
# ...                             ...       ...           ...       ...
# 2025-02-25 09:35:00+00:00  1.606194 -0.001493     -0.001493  0.973907
# 2025-02-25 09:40:00+00:00  1.932042 -0.000208     -0.000208  0.973704
# 2025-02-25 09:45:00+00:00  1.901096  0.000332      0.000332  0.974028
# 2025-02-25 09:50:00+00:00  1.947617 -0.001246     -0.001246  0.972814
# 2025-02-25 09:55:00+00:00  1.841271 -0.000291     -0.000291  0.972531
#
# Price                          CAGR
# Ticker
# Datetime
# 2025-01-27 03:45:00+00:00 -0.282373
# 2025-01-27 03:50:00+00:00 -0.282373
# 2025-01-27 03:55:00+00:00 -0.282373
# 2025-01-27 04:00:00+00:00 -0.282373
# 2025-01-27 04:05:00+00:00 -0.282373
# ...                             ...
# 2025-02-25 09:35:00+00:00 -0.282373
# 2025-02-25 09:40:00+00:00 -0.282373
# 2025-02-25 09:45:00+00:00 -0.282373
# 2025-02-25 09:50:00+00:00 -0.282373
# 2025-02-25 09:55:00+00:00 -0.282373
#
# [1650 rows x 14 columns]

# %%
data['RELIANCE.NS']
# Out:
# Price                            Close         High          Low         Open  \
# Ticker                     RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS
# Datetime
# 2025-01-27 03:45:00+00:00  1235.949951  1240.300049  1234.349976  1237.849976
# 2025-01-27 03:50:00+00:00  1236.750000  1238.300049  1234.300049  1235.750000
# 2025-01-27 03:55:00+00:00  1237.900024  1239.550049  1236.050049  1236.699951
# 2025-01-27 04:00:00+00:00  1236.550049  1239.400024  1235.050049  1237.900024
# 2025-01-27 04:05:00+00:00  1235.699951  1237.050049  1235.050049  1236.650024
# ...                                ...          ...          ...          ...
# 2025-02-25 09:35:00+00:00  1203.699951  1205.849976  1202.150024  1205.650024
# 2025-02-25 09:40:00+00:00  1203.449951  1206.750000  1202.699951  1203.000000
# 2025-02-25 09:45:00+00:00  1203.849976  1204.349976  1202.650024  1203.449951
# 2025-02-25 09:50:00+00:00  1202.349976  1203.900024  1201.650024  1203.849976
# 2025-02-25 09:55:00+00:00  1202.000000  1203.000000  1201.849976  1202.500000
#
# Price                          Volume H-L H-PC L-PC  TR ATR     d_rtn  \
# Ticker                    RELIANCE.NS
# Datetime
# 2025-01-27 03:45:00+00:00           0 NaN  NaN  NaN NaN NaN       NaN
# 2025-01-27 03:50:00+00:00      185499 NaN  NaN  NaN NaN NaN  0.000647
# 2025-01-27 03:55:00+00:00      134408 NaN  NaN  NaN NaN NaN  0.000930
# 2025-01-27 04:00:00+00:00      220512 NaN  NaN  NaN NaN NaN -0.001091
# 2025-01-27 04:05:00+00:00      121827 NaN  NaN  NaN NaN NaN -0.000687
# ...                               ...  ..  ...  ...  ..  ..       ...
# 2025-02-25 09:35:00+00:00      876141 NaN  NaN  NaN NaN NaN -0.001493
# 2025-02-25 09:40:00+00:00      626633 NaN  NaN  NaN NaN NaN -0.000208
# 2025-02-25 09:45:00+00:00      663120 NaN  NaN  NaN NaN NaN  0.000332
# 2025-02-25 09:50:00+00:00      583933 NaN  NaN  NaN NaN NaN -0.001246
# 2025-02-25 09:55:00+00:00      314805 NaN  NaN  NaN NaN NaN -0.000291
#
# Price                     daily_returns   cum_rtn      CAGR
# Ticker
# Datetime
# 2025-01-27 03:45:00+00:00           NaN       NaN -0.282373
# 2025-01-27 03:50:00+00:00      0.000647  1.000647 -0.282373
# 2025-01-27 03:55:00+00:00      0.000930  1.001578 -0.282373
# 2025-01-27 04:00:00+00:00     -0.001091  1.000486 -0.282373
# 2025-01-27 04:05:00+00:00     -0.000687  0.999798 -0.282373
# ...                                 ...       ...       ...
# 2025-02-25 09:35:00+00:00     -0.001493  0.973907 -0.282373
# 2025-02-25 09:40:00+00:00     -0.000208  0.973704 -0.282373
# 2025-02-25 09:45:00+00:00      0.000332  0.974028 -0.282373
# 2025-02-25 09:50:00+00:00     -0.001246  0.972814 -0.282373
# 2025-02-25 09:55:00+00:00     -0.000291  0.972531 -0.282373
#
# [1650 rows x 14 columns]
