# %%
## Cummulative Returns

# Cummulative Returns = (Ending Price - Starting Price)/Starting Price

# %% [markdown]
# # Libraries we need
# - Pandas
# - yfinance
# - matplotlib

# %%
# Import Libraries 
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
ticker = 'TSLA'

data = yf.download(tickers=ticker, interval='1d')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-12-27  449.519989  450.000000  426.500000  431.660004  431.660004
# 2024-12-30  419.399994  427.000000  415.750000  417.410004  417.410004
# 2024-12-31  423.790009  427.929993  402.540009  403.839996  403.839996
# 2025-01-02  390.100006  392.730011  373.040009  379.279999  379.279999
# 2025-01-03  381.654999  411.879913  379.450012  410.440002  410.440002
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %%
# calulate the Daily returns 
data['Daily Return'] = data['Adj Close'].pct_change()

# %%
# Cummulative Return
data['Cumulative Return'] = (1 + data['Daily Return']).cumprod()-1

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-12-27  449.519989  450.000000  426.500000  431.660004  431.660004
# 2024-12-30  419.399994  427.000000  415.750000  417.410004  417.410004
# 2024-12-31  423.790009  427.929993  402.540009  403.839996  403.839996
# 2025-01-02  390.100006  392.730011  373.040009  379.279999  379.279999
# 2025-01-03  381.654999  411.879913  379.450012  410.440002  410.440002
#
#                Volume  Daily Return  Cummulative Return
# Date
# 2024-12-27   82666800     -0.049479          270.029668
# 2024-12-30   64941000     -0.033012          261.082411
# 2024-12-31   76825100     -0.032510          252.562107
# 2025-01-02  109710700     -0.060816          237.141434
# 2025-01-03   93808487      0.082156          256.706103

# %%
# Visualize 

plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Cumulative Return'], label = 'Cumulative Return')
plt.xlabel('Years')
plt.ylabel('Cumulative Return')
plt.grid(True)
plt.legend()
plt.show()
